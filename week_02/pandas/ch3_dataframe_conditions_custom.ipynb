# %% [markdown]
# ## ch3 pandas dataframe
# 지난 챕터에 이어서 마찬가지로 데이터 프레임을 다루는 여러 기법들을 소개하겠습니다. 데이터 프레임에 조건을 걸어서 데이터를 가져오고, 특정 컬럼을 기준으로 정렬하는 등 실제 데이터 분석 작업에서 많이 사용하는 기법들을 배워보겠습니다. 데이터 셋은 마찬가지로 2019년 spotify 스트리밍 순위 데이터 셋을 사용하겠습니다.
#
# 데이터 셋: https://www.kaggle.com/datasets/prasertk/spotify-global-2019-moststreamed-tracks

# %%
import pandas as pd

df = pd.read_csv("./data/spotify_2019.csv")

# %%
import time

start = time.time()
df.describe()["Streams"]
print("소요시간", time.time() - start)
# Out:
# 소요시간 0.03373289108276367

# %%
start = time.time()
df["Streams"].describe()
print("소요시간", time.time() - start)
# Out:
# 소요시간 0.0025801658630371094

# %%
df
# Out:
#      Country    Rank                Track_id     Streams  \
# 0     global     1.0  25sgk305KZfyuqVBQIahim  1166185736
# 1     global     2.0  2Fxmhks0bxGSBdJ92vM42m  1052358787
# 2     global     3.0  6ocbgoVGwYJhOv1GgI9NsF   789094044
# 3     global     4.0  1rgnBhdG2JDFTbYkYRZAku   764208309
# 4     global     5.0  6v3KW9xbzN5yKLt9YKDYA2   763064359
# ...      ...     ...                     ...         ...
# 1712  global  1713.0  27SdWb2rFzO6GWiYDBTD9j      554971
# 1713  global  1714.0  0kLA41xkWzzYzMIEGFuDkP      544655
# 1714  global  1715.0  79hJaqmVdohltPBNN6BULM      536886
# 1715  global  1716.0  7rLegaz7zKB6EtDNzcslKE      536447
# 1716  global  1717.0  0kCqaybZgYcLYxzZymmBoc      524230
#
#                                              Track Name              Artist  \
# 0                                      Sweet but Psycho             Ava Max
# 1                                               bad guy       Billie Eilish
# 2                                               7 rings       Ariana Grande
# 3                                          Dance Monkey         Tones and I
# 4                                              Señorita        Shawn Mendes
# ...                                                 ...                 ...
# 1712                                      Cheap Thrills                 Sia
# 1713                             HaifischNikez Allstars                  LX
# 1714  Stayin' Alive - From "Saturday Night Fever" So...            Bee Gees
# 1715                 Medley da Gaiola - Dennis DJ Remix    MC Kevin o Chris
# 1716                        Quem Pegou, Pegou - Ao Vivo  Henrique & Juliano
#
#                                                     URL  acousticness  \
# 0     https://open.spotify.com/track/25sgk305KZfyuqV...        0.0691
# 1     https://open.spotify.com/track/2Fxmhks0bxGSBdJ...        0.3280
# 2     https://open.spotify.com/track/6ocbgoVGwYJhOv1...        0.5920
# 3     https://open.spotify.com/track/1rgnBhdG2JDFTbY...        0.6880
# 4     https://open.spotify.com/track/6v3KW9xbzN5yKLt...        0.0392
# ...                                                 ...           ...
# 1712  https://open.spotify.com/track/27SdWb2rFzO6GWi...        0.0472
# 1713  https://open.spotify.com/track/0kLA41xkWzzYzMI...        0.1620
# 1714  https://open.spotify.com/track/79hJaqmVdohltPB...        0.0700
# 1715  https://open.spotify.com/track/7rLegaz7zKB6EtD...        0.7110
# 1716  https://open.spotify.com/track/0kCqaybZgYcLYxz...        0.2990
#
#       danceability  energy  ...  valence    tempo  time_signature  \
# 0            0.719   0.704  ...    0.628  133.002               4
# 1            0.701   0.425  ...    0.562  135.128               4
# 2            0.778   0.317  ...    0.327  140.048               4
# 3            0.825   0.593  ...    0.540   98.078               4
# 4            0.759   0.548  ...    0.749  116.967               4
# ...            ...     ...  ...      ...      ...             ...
# 1712         0.628   0.698  ...    0.732   89.976               4
# 1713         0.764   0.744  ...    0.507   87.538               4
# 1714         0.708   0.567  ...    0.955  103.606               4
# 1715         0.896   0.756  ...    0.686  140.076               4
# 1716         0.690   0.670  ...    0.579  104.022               4
#
#       duration_ms  key  mode               Artist_id  Artist_popularity  \
# 0          187436    1     1  4npEfmQ6YuiwW1GpUmaq3F                 87
# 1          194088    7     1  6qqNVTkY8uBg9cP3Jd7DAH                 98
# 2          178627    1     0  66CXWjxzNUsdJxJ2JdwvnR                 97
# 3          209755    6     0  2NjfBq1NflQcKSeiDooVjY                 92
# 4          190800    9     0  7n2wHs1TKAczGzO7Dd2rGr                 94
# ...           ...  ...   ...                     ...                ...
# 1712       211667    6     0  5WUlDfRSoLAfcVSX1WnrxN                 90
# 1713       182925   11     0  10XY9PZCJKzUFzZOdtlQLU                 71
# 1714       281667   10     0  1LZEQNv7sE11VDY3SdxQeN                 79
# 1715       240000    4     0  2UMj7NCbuqy1yUZmiSYGjJ                 84
# 1716       184326    9     1  3p7PcrEHaaKLJnPUGOtRlT                 84
#
#       Artist_follower                                         Artist_img
# 0             1025358  https://i.scdn.co/image/4b914c6470c8458674538a...
# 1            18867904  https://i.scdn.co/image/2622edec99d68d1d141886...
# 2            40958727  https://i.scdn.co/image/b1dfbe843b0b9f54ab2e58...
# 3              484241  https://i.scdn.co/image/c128f5ef4d210a67610acd...
# 4            23152263  https://i.scdn.co/image/6bd59cfbd3e1e6394af710...
# ...               ...                                                ...
# 1712         15317280  https://i.scdn.co/image/652b6bb0dfaf8aa444f441...
# 1713            64625  https://i.scdn.co/image/60d0c075d6de8417a0c44d...
# 1714          2834719  https://i.scdn.co/image/1d5a05673975ba0c378cd2...
# 1715          1139072  https://i.scdn.co/image/984dfbcdcf7880b022478b...
# 1716          9577443  https://i.scdn.co/image/f9e65e111cbb16276d2c27...
#
# [1717 rows x 24 columns]

# %% [markdown]
# ### 특정 조건에 맞는 행들만 가져오기

# %% [markdown]
# 특정 컬럼에 조건을 걸어서 조건에 일치하는 행들만 가져오고 싶으면 아래처럼 인덱스에 부등식을 활용하면 됩니다. 데이터 프레임에서 스트리밍 횟수가 1억회 이상인 트랙들만 추출해보겠습니다.

# %%
df[df["Streams"] >= 100000000]
# Out:
#     Country   Rank                Track_id     Streams  \
# 0    global    1.0  25sgk305KZfyuqVBQIahim  1166185736
# 1    global    2.0  2Fxmhks0bxGSBdJ92vM42m  1052358787
# 2    global    3.0  6ocbgoVGwYJhOv1GgI9NsF   789094044
# 3    global    4.0  1rgnBhdG2JDFTbYkYRZAku   764208309
# 4    global    5.0  6v3KW9xbzN5yKLt9YKDYA2   763064359
# ..      ...    ...                     ...         ...
# 261  global  262.0  543bCW2ruMPmxUBWirQ3MR   100909750
# 262  global  263.0  6RyaV7owmVU6fzEPE17sF1   100464346
# 263  global  264.0  6WkJ2OK163XXS2oARUC9JM   100432584
# 264  global  265.0  1Slwb6dOYkBlWal1PGtnNg   100347749
# 265  global  266.0  3Yh9lZcWyKrK9GjbhuS0hR   100158110
#
#                                         Track Name         Artist  \
# 0                                 Sweet but Psycho        Ava Max
# 1                                          bad guy  Billie Eilish
# 2                                          7 rings  Ariana Grande
# 3                                     Dance Monkey    Tones and I
# 4                                         Señorita   Shawn Mendes
# ..                                             ...            ...
# 261  Cross Me (feat. Chance the Rapper & PnB Rock)     Ed Sheeran
# 262                              Que Tire Pa Lante   Daddy Yankee
# 263             Dancin (feat. Luvli) - Krono Remix    Aaron Smith
# 264                              Thinking out Loud     Ed Sheeran
# 265                                   Good as Hell          Lizzo
#
#                                                    URL  acousticness  \
# 0    https://open.spotify.com/track/25sgk305KZfyuqV...        0.0691
# 1    https://open.spotify.com/track/2Fxmhks0bxGSBdJ...        0.3280
# 2    https://open.spotify.com/track/6ocbgoVGwYJhOv1...        0.5920
# 3    https://open.spotify.com/track/1rgnBhdG2JDFTbY...        0.6880
# 4    https://open.spotify.com/track/6v3KW9xbzN5yKLt...        0.0392
# ..                                                 ...           ...
# 261  https://open.spotify.com/track/543bCW2ruMPmxUB...        0.2140
# 262  https://open.spotify.com/track/6RyaV7owmVU6fzE...        0.0478
# 263  https://open.spotify.com/track/6WkJ2OK163XXS2o...        0.1010
# 264  https://open.spotify.com/track/1Slwb6dOYkBlWal...        0.4740
# 265  https://open.spotify.com/track/3Yh9lZcWyKrK9Gj...        0.2560
#
#      danceability  energy  ...  valence    tempo  time_signature  duration_ms  \
# 0           0.719   0.704  ...    0.628  133.002               4       187436
# 1           0.701   0.425  ...    0.562  135.128               4       194088
# 2           0.778   0.317  ...    0.327  140.048               4       178627
# 3           0.825   0.593  ...    0.540   98.078               4       209755
# 4           0.759   0.548  ...    0.749  116.967               4       190800
# ..            ...     ...  ...      ...      ...             ...          ...
# 261         0.746   0.787  ...    0.607   95.005               4       206187
# 262         0.658   0.901  ...    0.708   93.979               4       210520
# 263         0.720   0.741  ...    0.357  119.896               4       198053
# 264         0.781   0.445  ...    0.591   78.998               4       281560
# 265         0.682   0.919  ...    0.535   95.982               4       159736
#
#      key  mode               Artist_id  Artist_popularity  Artist_follower  \
# 0      1     1  4npEfmQ6YuiwW1GpUmaq3F                 87          1025358
# 1      7     1  6qqNVTkY8uBg9cP3Jd7DAH                 98         18867904
# 2      1     0  66CXWjxzNUsdJxJ2JdwvnR                 97         40958727
# 3      6     0  2NjfBq1NflQcKSeiDooVjY                 92           484241
# 4      9     0  7n2wHs1TKAczGzO7Dd2rGr                 94         23152263
# ..   ...   ...                     ...                ...              ...
# 261    4     1  6eUKZXaKkcviH0Ku9w2n3V                 98         57463755
# 262    7     1  4VMYDCV2IEDYJArk749S6m                 95         15857952
# 263   10     0  77qukKzmdI5BeMBR7WGUrN                 74           181543
# 264    2     1  6eUKZXaKkcviH0Ku9w2n3V                 98         57463755
# 265    0     0  56oDRnqbIiwx4mymNEv7dS                 88          1838446
#
#                                             Artist_img
# 0    https://i.scdn.co/image/4b914c6470c8458674538a...
# 1    https://i.scdn.co/image/2622edec99d68d1d141886...
# 2    https://i.scdn.co/image/b1dfbe843b0b9f54ab2e58...
# 3    https://i.scdn.co/image/c128f5ef4d210a67610acd...
# 4    https://i.scdn.co/image/6bd59cfbd3e1e6394af710...
# ..                                                 ...
# 261  https://i.scdn.co/image/f55cab0739390cf3b2c2f7...
# 262  https://i.scdn.co/image/01dae15758ba1a3d18e6e3...
# 263  https://i.scdn.co/image/ead4661fcddfe229e2e07d...
# 264  https://i.scdn.co/image/f55cab0739390cf3b2c2f7...
# 265  https://i.scdn.co/image/e33e4245fe5901ed940ba9...
#
# [266 rows x 24 columns]

# %% [markdown]
# ### 조건 중첩시키기
# 여러 조건을 중첩시켜서 데이터를 가져오고 싶다면 "&", "|" 기호를 사용하여 조건을 중첩하면 된다. 이 때, 반드시 각 조건을 괄호로 한번 감싸주어야 에러가 나지 않는다. 한번 조회 수가 1억 이상인 동시에 tempo가 120 이상인 트랙만 가져와보자.

# %%
a = [1, 2, 3]

# %%
df[(df["Streams"] >= 100000000) & (df["tempo"] >= 120)][["Streams", "tempo"]]
# Out:
#         Streams    tempo
# 0    1166185736  133.002
# 1    1052358787  135.128
# 2     789094044  140.048
# 10    605653817  136.041
# 11    591435651  126.899
# ..          ...      ...
# 250   105576121  124.948
# 252   104635897  171.017
# 254   103945719  123.935
# 256   103587011  154.355
# 260   101244428  154.983
#
# [118 rows x 2 columns]

# %% [markdown]
# ### dataframe 정렬하기
# df.sort_values()를 이용하면 특정 컬럼을 기준으로 데이터 프레임을 소팅할 수 있습니다. 한번 Artist_popularity가 높은 순으로 데이터 프레임을 정렬한 후, 상위 10명의 아티스트를 출력해보겠습니다.

# %%
df.sort_values(
    by=["Artist_popularity"], 
    ascending=False
)[["Artist", "Artist_popularity"]].iloc[:10]
# Out:
#           Artist  Artist_popularity
# 639  Post Malone                100
# 923  Post Malone                100
# 125  Post Malone                100
# 31   Post Malone                100
# 33   Post Malone                100
# 112  Post Malone                100
# 545  Post Malone                100
# 544  Post Malone                100
# 538  Post Malone                100
# 290  Post Malone                100

# %% [markdown]
# ### dataframe 중복 제거하기
# 앞서 인기 순으로 정렬해서 아티스트를 가져와보면 "포스트 말론", 100이 중복해서 리턴 되었습니다. 만약 우리가 데이터 베이스에서 동일한 작업을 수행한다고 했을 때, SQL문을 작성하면 DISTINCT를 사용했을 것입니다. 비슷하게 df.drop_duplicates를 사용해서 결과로 리턴된 데이터 프레임의 중복을 제거해보겠습니다.

# %%
df.sort_values(
    by=["Artist_popularity"], 
    ascending=False
)[["Artist", "Artist_popularity"]].drop_duplicates()[:10]
# Out:
#              Artist  Artist_popularity
# 639     Post Malone                100
# 1400          Drake                 99
# 1067       J Balvin                 99
# 1021      Bad Bunny                 98
# 257   Billie Eilish                 98
# 560      Ed Sheeran                 98
# 801           Ozuna                 98
# 813      Juice WRLD                 98
# 1157   Travis Scott                 98
# 187   Ariana Grande                 97

# %% [markdown]
# ### dataframe 인덱스 재설정하기
# 원하는 대로 데이터를 가져왔습니다만, 행 맨앞에 붙어있는 인덱스가 트랙 인덱스 그대로 붙어있어서 거슬립니다. df.reset_index()를 이용해서 재설정 해주겠습니다.

# %%
df.sort_values(
    by=["Artist_popularity"], 
    ascending=False
)[["Artist", "Artist_popularity"]].drop_duplicates()[:10].reset_index(drop=True)
# Out:
#           Artist  Artist_popularity
# 0    Post Malone                100
# 1          Drake                 99
# 2       J Balvin                 99
# 3      Bad Bunny                 98
# 4  Billie Eilish                 98
# 5     Ed Sheeran                 98
# 6          Ozuna                 98
# 7     Juice WRLD                 98
# 8   Travis Scott                 98
# 9  Ariana Grande                 97

# %% [markdown]
# ### 연습문제
# dataframe을 이용해서 아래 문제들을 풀어보세요.
#
# 1. 트랙에 포함된 BTS의 노래들의 이름과 스트리밍 횟수를 리턴하세요. 트랙 이름으로 오름차순 정렬을 하세요.

# %%
df[df["Artist"]=="BTS"][["Track Name", "Streams"]].sort_values(by=["Track Name"]).reset_index(drop=True)
# Out:
#                                            Track Name    Streams
# 0   A Brand New Day (BTS World Original Soundtrack...    4383131
# 1   All Night (BTS World Original Soundtrack) [Pt. 3]    1921011
# 2                         Boy With Luv (feat. Halsey)  261504425
# 3                                            Dionysus   15134946
# 4   Dream Glow (BTS World Original Soundtrack) - P...   18648089
# 5                                                HOME   16442038
# 6                                     Intro : Persona    8775556
# 7                                           Jamais Vu   12992565
# 8                                       Make It Right   18423901
# 9                          Make It Right (feat. Lauv)   42873724
# 10                                        Mikrokosmos   18801822

# %% [markdown]
# 2. BTS의 track들의 Streams, energy, Rank, tempo의 통계량을 집계해보세요.

# %%
df[df["Artist"]=="BTS"][["Streams", "energy", "Rank", "tempo"]].describe()
# Out:
#             Streams     energy         Rank       tempo
# count  1.100000e+01  11.000000    11.000000   11.000000
# mean   3.817284e+07   0.736455   728.545455  122.822000
# std    7.483497e+07   0.146617   302.115661   32.488069
# min    1.921011e+06   0.470000    87.000000   81.000000
# 25%    1.088406e+07   0.694000   678.000000  101.279500
# 50%    1.644204e+07   0.740000   711.000000  119.991000
# 75%    1.872496e+07   0.860000   831.500000  142.469500
# max    2.615044e+08   0.910000  1266.000000  176.084000

# %% [markdown]
# 3. 템포가 100 이하이거나 energy가 0.6 이하인 노래들 가운데 스트리밍 횟수가 높은 노래 10개의 제목과 아티스트, 템포, 스트리밍 횟수를 가져오세요.

# %%
df.reset_index(drop=True)

# %%
df[(df["tempo"] <= 100) | (df["energy"] <= 0.6)].sort_values(by=["Artist_popularity"], ascending=False)[["Artist", "Artist Popularity", "Track Name"]].iloc[:1]
# Out:
#     Country   Rank                Track_id    Streams  \
# 125  global  126.0  3swc6WTsr7rl9DqQKQA55C  195603663
# 661  global  662.0  4hDoWaIklSVAKLocU3IDBr   20316233
# 290  global  291.0  0Xek5rqai2jcOWCYWJfVCF   92853630
# 781  global  782.0  5KE9b4x7Zj2A8XtbkqhqTe   12956366
# 775  global  776.0  1ckLp8lCl8LipXI0ypX72m   13110741
# 33   global   34.0  0e7ipj03S05BNilyu5bRzt  395449434
# 31   global   32.0  7dt6x5M1jzdTEt8oCbisTK  405953336
# 743  global  744.0  4RzpCjByV1NWUGKVQGuej6   14360613
# 234  global  235.0  7xQAfvXzm3AkraOtGPWIZg  114072916
# 112  global  113.0  0RiRZpuVRbi7oqRdSMwhQY  209280692
#
#                                         Track Name       Artist  \
# 125                   Psycho (feat. Ty Dolla $ign)  Post Malone
# 661                                   I'm Gonna Be  Post Malone
# 290                         Enemies (feat. DaBaby)  Post Malone
# 781                 Staring At The Sun (feat. SZA)  Post Malone
# 775                                   I'm Gonna Be  Post Malone
# 33                      rockstar (feat. 21 Savage)  Post Malone
# 31                                      Better Now  Post Malone
# 743                                       Internet  Post Malone
# 234                                           Wow.  Post Malone
# 112  Sunflower - Spider-Man: Into the Spider-Verse  Post Malone
#
#                                                    URL  acousticness  \
# 125  https://open.spotify.com/track/3swc6WTsr7rl9Dq...        0.5460
# 661  https://open.spotify.com/track/4hDoWaIklSVAKLo...        0.7030
# 290  https://open.spotify.com/track/0Xek5rqai2jcOWC...        0.0588
# 781  https://open.spotify.com/track/5KE9b4x7Zj2A8Xt...        0.2480
# 775  https://open.spotify.com/track/1ckLp8lCl8LipXI...        0.7030
# 33   https://open.spotify.com/track/0e7ipj03S05BNil...        0.1240
# 31   https://open.spotify.com/track/7dt6x5M1jzdTEt8...        0.3310
# 743  https://open.spotify.com/track/4RzpCjByV1NWUGK...        0.8410
# 234  https://open.spotify.com/track/7xQAfvXzm3AkraO...        0.1360
# 112  https://open.spotify.com/track/0RiRZpuVRbi7oqR...        0.5330
#
#      danceability  energy  ...  valence    tempo  time_signature  duration_ms  \
# 125         0.750   0.560  ...    0.459  140.060               4       221440
# 661         0.746   0.559  ...    0.368  117.943               4       200680
# 290         0.542   0.674  ...    0.667   76.388               4       196760
# 781         0.724   0.772  ...    0.347   95.074               4       168280
# 775         0.746   0.559  ...    0.368  117.943               4       200680
# 33          0.585   0.520  ...    0.129  159.801               4       218147
# 31          0.680   0.578  ...    0.341  145.038               4       231267
# 743         0.469   0.489  ...    0.201   74.013               4       123387
# 234         0.829   0.539  ...    0.388   99.960               4       149547
# 112         0.755   0.522  ...    0.925   89.960               4       157560
#
#      key  mode               Artist_id  Artist_popularity  Artist_follower  \
# 125    8     1  246dkjvS1zLTtiykXe5h60                100         21335421
# 661    5     1  246dkjvS1zLTtiykXe5h60                100         21335421
# 290    6     1  246dkjvS1zLTtiykXe5h60                100         21335421
# 781    6     0  246dkjvS1zLTtiykXe5h60                100         21335421
# 775    5     1  246dkjvS1zLTtiykXe5h60                100         21335421
# 33     5     0  246dkjvS1zLTtiykXe5h60                100         21335421
# 31    10     1  246dkjvS1zLTtiykXe5h60                100         21335421
# 743    0     1  246dkjvS1zLTtiykXe5h60                100         21335421
# 234   11     0  246dkjvS1zLTtiykXe5h60                100         21335421
# 112    2     1  246dkjvS1zLTtiykXe5h60                100         21335421
#
#                                             Artist_img
# 125  https://i.scdn.co/image/93fec27f9aac86526b9010...
# 661  https://i.scdn.co/image/93fec27f9aac86526b9010...
# 290  https://i.scdn.co/image/93fec27f9aac86526b9010...
# 781  https://i.scdn.co/image/93fec27f9aac86526b9010...
# 775  https://i.scdn.co/image/93fec27f9aac86526b9010...
# 33   https://i.scdn.co/image/93fec27f9aac86526b9010...
# 31   https://i.scdn.co/image/93fec27f9aac86526b9010...
# 743  https://i.scdn.co/image/93fec27f9aac86526b9010...
# 234  https://i.scdn.co/image/93fec27f9aac86526b9010...
# 112  https://i.scdn.co/image/93fec27f9aac86526b9010...
#
# [10 rows x 24 columns]

# %%
df[["Artist", "Artist_popularity", "Track Name", "tempo"]].sort_values(by=["Artist_popularity", "tempo"])
# Out:
#                      Artist  Artist_popularity  \
# 1343  Bobby "Boris" Pickett                 47
# 1474            Herve Pagez                 55
# 1348           John Lundvik                 56
# 1336                 Keiino                 56
# 1321             Luca Hänni                 57
# ...                     ...                ...
# 598             Post Malone                100
# 608             Post Malone                100
# 33              Post Malone                100
# 721             Post Malone                100
# 917             Post Malone                100
#
#                            Track Name    tempo
# 1343                     Monster Mash   68.482
# 1474  Spicy - with Diplo & Charli XCX  109.993
# 1348                Too Late For Love  104.252
# 1336                Spirit in the Sky  121.952
# 1321                       She Got Me   97.063
# ...                               ...      ...
# 598              A Thousand Bad Times  159.000
# 608              A Thousand Bad Times  159.000
# 33         rockstar (feat. 21 Savage)  159.801
# 721                            Myself  163.882
# 917                            Myself  163.882
#
# [1717 rows x 4 columns]

# %%
df
# Out:
#      Country    Rank                Track_id     Streams  \
# 0     global     1.0  25sgk305KZfyuqVBQIahim  1166185736
# 1     global     2.0  2Fxmhks0bxGSBdJ92vM42m  1052358787
# 2     global     3.0  6ocbgoVGwYJhOv1GgI9NsF   789094044
# 3     global     4.0  1rgnBhdG2JDFTbYkYRZAku   764208309
# 4     global     5.0  6v3KW9xbzN5yKLt9YKDYA2   763064359
# ...      ...     ...                     ...         ...
# 1712  global  1713.0  27SdWb2rFzO6GWiYDBTD9j      554971
# 1713  global  1714.0  0kLA41xkWzzYzMIEGFuDkP      544655
# 1714  global  1715.0  79hJaqmVdohltPBNN6BULM      536886
# 1715  global  1716.0  7rLegaz7zKB6EtDNzcslKE      536447
# 1716  global  1717.0  0kCqaybZgYcLYxzZymmBoc      524230
#
#                                              Track Name              Artist  \
# 0                                      Sweet but Psycho             Ava Max
# 1                                               bad guy       Billie Eilish
# 2                                               7 rings       Ariana Grande
# 3                                          Dance Monkey         Tones and I
# 4                                              Señorita        Shawn Mendes
# ...                                                 ...                 ...
# 1712                                      Cheap Thrills                 Sia
# 1713                             HaifischNikez Allstars                  LX
# 1714  Stayin' Alive - From "Saturday Night Fever" So...            Bee Gees
# 1715                 Medley da Gaiola - Dennis DJ Remix    MC Kevin o Chris
# 1716                        Quem Pegou, Pegou - Ao Vivo  Henrique & Juliano
#
#                                                     URL  acousticness  \
# 0     https://open.spotify.com/track/25sgk305KZfyuqV...        0.0691
# 1     https://open.spotify.com/track/2Fxmhks0bxGSBdJ...        0.3280
# 2     https://open.spotify.com/track/6ocbgoVGwYJhOv1...        0.5920
# 3     https://open.spotify.com/track/1rgnBhdG2JDFTbY...        0.6880
# 4     https://open.spotify.com/track/6v3KW9xbzN5yKLt...        0.0392
# ...                                                 ...           ...
# 1712  https://open.spotify.com/track/27SdWb2rFzO6GWi...        0.0472
# 1713  https://open.spotify.com/track/0kLA41xkWzzYzMI...        0.1620
# 1714  https://open.spotify.com/track/79hJaqmVdohltPB...        0.0700
# 1715  https://open.spotify.com/track/7rLegaz7zKB6EtD...        0.7110
# 1716  https://open.spotify.com/track/0kCqaybZgYcLYxz...        0.2990
#
#       danceability  energy  ...  valence    tempo  time_signature  \
# 0            0.719   0.704  ...    0.628  133.002               4
# 1            0.701   0.425  ...    0.562  135.128               4
# 2            0.778   0.317  ...    0.327  140.048               4
# 3            0.825   0.593  ...    0.540   98.078               4
# 4            0.759   0.548  ...    0.749  116.967               4
# ...            ...     ...  ...      ...      ...             ...
# 1712         0.628   0.698  ...    0.732   89.976               4
# 1713         0.764   0.744  ...    0.507   87.538               4
# 1714         0.708   0.567  ...    0.955  103.606               4
# 1715         0.896   0.756  ...    0.686  140.076               4
# 1716         0.690   0.670  ...    0.579  104.022               4
#
#       duration_ms  key  mode               Artist_id  Artist_popularity  \
# 0          187436    1     1  4npEfmQ6YuiwW1GpUmaq3F                 87
# 1          194088    7     1  6qqNVTkY8uBg9cP3Jd7DAH                 98
# 2          178627    1     0  66CXWjxzNUsdJxJ2JdwvnR                 97
# 3          209755    6     0  2NjfBq1NflQcKSeiDooVjY                 92
# 4          190800    9     0  7n2wHs1TKAczGzO7Dd2rGr                 94
# ...           ...  ...   ...                     ...                ...
# 1712       211667    6     0  5WUlDfRSoLAfcVSX1WnrxN                 90
# 1713       182925   11     0  10XY9PZCJKzUFzZOdtlQLU                 71
# 1714       281667   10     0  1LZEQNv7sE11VDY3SdxQeN                 79
# 1715       240000    4     0  2UMj7NCbuqy1yUZmiSYGjJ                 84
# 1716       184326    9     1  3p7PcrEHaaKLJnPUGOtRlT                 84
#
#       Artist_follower                                         Artist_img
# 0             1025358  https://i.scdn.co/image/4b914c6470c8458674538a...
# 1            18867904  https://i.scdn.co/image/2622edec99d68d1d141886...
# 2            40958727  https://i.scdn.co/image/b1dfbe843b0b9f54ab2e58...
# 3              484241  https://i.scdn.co/image/c128f5ef4d210a67610acd...
# 4            23152263  https://i.scdn.co/image/6bd59cfbd3e1e6394af710...
# ...               ...                                                ...
# 1712         15317280  https://i.scdn.co/image/652b6bb0dfaf8aa444f441...
# 1713            64625  https://i.scdn.co/image/60d0c075d6de8417a0c44d...
# 1714          2834719  https://i.scdn.co/image/1d5a05673975ba0c378cd2...
# 1715          1139072  https://i.scdn.co/image/984dfbcdcf7880b022478b...
# 1716          9577443  https://i.scdn.co/image/f9e65e111cbb16276d2c27...
#
# [1717 rows x 24 columns]
